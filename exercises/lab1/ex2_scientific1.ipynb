# %% [markdown]
# # ex2_scientific1

# %% [markdown]
# ## Nội dung bài
# Hiển thị ngẫu nhiên $N=50$ hình tròn:
# + Tâm $c_i = (x_i,y_i)$ ngẫu nhiên với $x_i, y_i \in \left[0, 1 \right]$
# + Màu sắc $color_i$ ngẫu nhiên với $color_i \in \left[0, 1 \right]$
# + Diện tích $area_i = \pi * r_i^2$ với sinh ngẫu nhiên $r_i \in \left[0, 1 \right]$

# %% [markdown]
# ## Bài làm

# %% [markdown]
# ### Import thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display # hiển thị rich output

# %% [markdown]
# ### Sinh ngẫu nhiên hình tròn

# %%
# %time
# generate randomly the center (x,y ) of circle, color, area
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2  # 0 to 15 point radii
# Out:
# CPU times: user 3 μs, sys: 1 μs, total: 4 μs
# Wall time: 7.39 μs

# %%
# Mã kiểm tra dữ liệu
print(f'+ x: len={len(x):d}, [{min(x):.2f}, {max(x):.2f}]: 10 samples [{x[0:10]}]')
print(f'+ y: len={len(y):d}, [{min(y):.2f}, {max(y):.2f}]: 10 samples [{y[0:10]}]')
print(f'+ colors: len={len(colors):d}, [{min(colors):.2f}, {max(colors):.2f}]: 10 samples [{colors[0:10]}]')
print(f'+ area: len={len(area):d}, [{min(area):.2f}, {max(area):.2f}]: 10 samples [{area[0:10]}]')
# Out:
# + x: len=50, [0.00, 0.97]: 10 samples [[0.24688616 0.53078748 0.62811664 0.3033175  0.17406294 0.70084843
#  0.09196682 0.10148471 0.09287555 0.16800931]]
# + y: len=50, [0.04, 1.00]: 10 samples [[0.86612993 0.26379635 0.96014982 0.40443297 0.72308409 0.34027833
#  0.85100114 0.9475951  0.0436418  0.05610196]]
# + colors: len=50, [0.00, 0.90]: 10 samples [[0.72970449 0.71309835 0.82841886 0.36535548 0.70162478 0.82881373
#  0.8764239  0.59068747 0.37553764 0.01096915]]
# + area: len=50, [0.00, 681.55]: 10 samples [[181.92148035  19.32303998  20.91892525 493.96624188 261.84592325
#    0.89587426 218.67439582 226.28272211  22.82268219  15.38340883]]

# %% [markdown]
# ### Hiển thị đồ thị

# %%
# %matplotlib inline
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# ## Kết thúc

# %%
# !jupyter nbconvert --to html ex2_scientific1.ipynb
# Out:
# [NbConvertApp] Converting notebook ex2_scientific1.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 1 image(s).
# [NbConvertApp] Writing 334583 bytes to ex2_scientific1.html
